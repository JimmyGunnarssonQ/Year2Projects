# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np 
#dataframe = pd.read_csv("mini.csv", sep=";")
#d1 = pd.read_csv("green.csv", sep=";")
#d2 = pd.read_csv("orange.csv", sep=";")
d3 = pd.read_csv("white.csv", sep=";")
#dataframe.head()
#l =dataframe["one"].str.replace('[A-Za-z]', '').str.replace('.', '').str.replace(',', '.').astype(float)
#m=dataframe["two"].str.replace('[A-Za-z]', '').str.replace('.', '').str.replace(',', '.').astype(float)

#l1=d1["one"].str.replace('[A-Za-z]', '').str.replace('.', '').str.replace(',', '.').astype(float)
#m1=d1["two"].str.replace('[A-Za-z]', '').str.replace('.', '').str.replace(',', '.').astype(float)

#l2 =d2["one"].str.replace('[A-Za-z]', '').str.replace('.', '').str.replace(',', '.').astype(float)
#m2=d2["two"].str.replace('[A-Za-z]', '').str.replace('.', '').str.replace(',', '.').astype(float)

l3 =d3["one"].str.replace('[A-Za-z]', '').str.replace('.', '').str.replace(',', '.').astype(float)
m3=d3["two"].str.replace('[A-Za-z]', '').str.replace('.', '').str.replace(',', '.').astype(float)


plt.figure(figsize=(10,10))
plt.plot(l3,m3, color = "red", label = "Reference spectrum")
#plt.plot(l[600:],m[600:], label="Emission spectrum")
#plt.plot(l1,m1, color = "green", label = "green")
#plt.plot(l2,m2, color = "orange", label = "orange")
plt.ylabel("intensity")
plt.xlabel("Wave length (nm)")
plt.title("Reference spectrum for task 1")
plt.grid()
#np.max(dataframe["one"][:])
#plt.plot([744,724,692,664.5], [25.8,25.8,25.8,15.8], "o", markersize = "10", color = "magenta", label = "Resonance points")
#plt.plot([636], [25], "o")
#plt.plot([545], [9.3], "o", color = "green", label = "green mean" )
#plt.plot([605], [8.5], "o", color = "orange", label = "orange mean")

plt.legend()
